# %%
import pandas as pd
pd.set_option('display.max_rows', 500)

# %%
price = pd.read_csv('../data/prices_plus_salty_siren.csv')

# %%
price
# Out:
#                                            drink_type  price_small  \
# 0                                          frappucino          5.0
# 1                                      iced chocolate          5.0
# 2                                     iced chai latte          5.0
# 3                                   milkshake (syrup)          4.6
# 4                   milkshake (natural fruit extract)          4.6
# 5                                     cold brew latte          4.5
# 6                                    iced coco matcha          5.0
# 7            company ice tea passion fruit and citrus          3.5
# 8           company ice tea raspberry and elderflower          3.5
# 9                               company ice tea peach          3.5
# 10                              special company drink          3.8
# 11                 smoothie - Kiwi Banana Mango Apple          4.9
# 12  smoothie - Strawberry Blueberry Blackcurrant M...          4.9
# ...

# %%
price.isna()
# Out:
#     drink_type  price_small  price_medium  price_large  simple  double
# 0        False        False         False        False    True    True
# 1        False        False         False        False    True    True
# 2        False        False         False        False    True    True
# 3        False        False         False        False    True    True
# 4        False        False         False        False    True    True
# 5        False        False         False        False    True    True
# 6        False        False         False        False    True    True
# 7        False        False         False        False    True    True
# 8        False        False         False        False    True    True
# 9        False        False         False        False    True    True
# 10       False        False         False        False    True    True
# 11       False        False         False        False    True    True
# ...

# %%
price.info
# Out:
# <bound method DataFrame.info of                                            drink_type  price_small  \
# 0                                          frappucino          5.0
# 1                                      iced chocolate          5.0
# 2                                     iced chai latte          5.0
# 3                                   milkshake (syrup)          4.6
# 4                   milkshake (natural fruit extract)          4.6
# 5                                     cold brew latte          4.5
# 6                                    iced coco matcha          5.0
# 7            company ice tea passion fruit and citrus          3.5
# 8           company ice tea raspberry and elderflower          3.5
# 9                               company ice tea peach          3.5
# 10                              special company drink          3.8
# 11                 smoothie - Kiwi Banana Mango Apple          4.9
# ...

# %%
price.last
# Out:
# <bound method NDFrame.last of                                            drink_type  price_small  \
# 0                                          frappucino          5.0
# 1                                      iced chocolate          5.0
# 2                                     iced chai latte          5.0
# 3                                   milkshake (syrup)          4.6
# 4                   milkshake (natural fruit extract)          4.6
# 5                                     cold brew latte          4.5
# 6                                    iced coco matcha          5.0
# 7            company ice tea passion fruit and citrus          3.5
# 8           company ice tea raspberry and elderflower          3.5
# 9                               company ice tea peach          3.5
# 10                              special company drink          3.8
# 11                 smoothie - Kiwi Banana Mango Apple          4.9
# 12  smoothie - Strawberry Blueberry Blackcurrant M...          4.9
# ...

# %%
price2 = price

# %%
price2 = price2.fillna(0)

# %%
price2['one_of_each'] = price2['price_small'] + price2['price_medium'] + price2['price_large'] + price2['simple'] + price2['double']

# %%
price2

# %%
price.info

# %%
salty_price = price.iloc[15]
salty_price = salty_price.dropna()
salty_price

# %%
price.price_large.sum() / 28

# %%
price.price_medium.sum() / 28

# %%
price.price_small.sum() / 28
## avg small price ##

# %%
price.simple.sum() / 28

# %%
price.double.sum() / 28

# %%
price.shape

# %%
recipes = pd.read_csv('../Data/recipes_plus_salty_siren.csv')
specs = recipes
specs

# %%
specs['fruit packets'].value_counts()

# %%
specs['size (coffee)'].value_counts()

# %%
specs.columns

# %%
specs['honey (in grams)'].value_counts()

# %%
salty_recipe = specs.iloc[45]
salty_recipe = salty_recipe.dropna()
salty_recipe

# %%
salty_price

# %%
salty_recipe

# %%
specs.columns

# %%
specs['milk (in cl)'].sum()

# %%
specs['ice cubes'].sum()

# %%
specs['coffee dose (in number of ristrettos)'].sum()

# %%
specs['coffee dose (in number of espressos)'].sum()

# %%
specs['tablespoon powder (= 15ml)'].sum()

# %%
specs.isna()

# %%
nulls = specs.isna().sum()

# %%
nulls

# %%
nulls = nulls.to_frame()

# %%
nulls

# %%
nulls.sum()

# %%
nulls.mean()

# %%
nulls.median()

# %%
nulls.mode()

# %%
nulls.info
